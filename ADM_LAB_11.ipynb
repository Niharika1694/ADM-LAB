# %% [markdown]
# <a href="https://colab.research.google.com/github/Niharika1694/ADM-LAB/blob/main/ADM_LAB_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
np.random.seed(42)
X = np.random.rand(100, 1) * 10
Y = 2.5 * X + np.random.randn(100, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)

# %%
print(f"Slope (Coefficient): {model.coef_[0][0]}")
print(f"Intercept: {model.intercept_[0]}")
# Out:
# Slope (Coefficient): 2.4598647314960562
# Intercept: 0.142913319458561

# %%
plt.scatter(X, Y, color='blue', label='Original Data')
plt.plot(X_test, Y_pred, color='red', label='Regression Line')
plt.xlabel('Independent Variable (X)')
plt.ylabel('Dependent Variable (Y)')
plt.legend()
plt.show()

# %%
data = pd.read_csv('salary_data.csv')
X = data['YearsExperience'].values.reshape(-1, 1)
y = data['Salary'].values
plt.scatter(X, y, color='blue', label='Data points')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)
model = LinearRegression()
model.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_poly)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
plt.scatter(X, y, color='blue', label='Data points')
plt.plot(X, y_pred, color='red', label='Polynomial fit')
plt.title('Polynomial Regression Fit')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 26446769.60683776
# R² Score: 0.9635969766249464
